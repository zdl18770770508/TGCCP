# %%
APS_path =  'D:/zncjStudyFile/毕业论文/code/CTPIR-master/data/APS/temporal/'
import networkx as nx
import numpy as np
import collections
import pickle
from datetime import datetime
import random
years=[1995,1996,1997,1998,1999,2000,2001,2002,2003,2004]
for year in years:
    with open(AIPatent_path+'/temporal_graph_'+str(1995), 'rb') as f:
        tmp = pickle.load(f)
#         print list(tmp.popitem.values())
        sample_5=random.sample(list(tmp),1)
        print list(sample_5.values())
# Out:
#   Input In [21]
#     print list(sample_5.values())
#           ^
# SyntaxError: invalid syntax

# %%
AIPatent_path =  'D:/zncjStudyFile/毕业论文/code/CTPIR-master/data/APS/temporal/'
Sample_mixTask_path = 'D:/zncjStudyFile/毕业论文/code/CTPIR-master/data/APS/sample/mixTask'
citation_10_path = 'D:/zncjStudyFile/毕业论文/code/CTPIR-master/data/APS/citation'
source_path = 'D:/zncjStudyFile/毕业论文/code/CTPIR-master/data/APS//source'
path = "D:/zncjStudyFile/毕业论文/dataSet/"
import networkx as nx
import numpy as np
import collections
import pickle
from datetime import datetime
# years = [2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021]
# years=[1995,1996,1997,1998,1999,2000,2001,2002,2003,2004]
years=[1995]
for year in years:
    with open(AIPatent_path+'/temporal_graph_'+str(year), 'rb') as f:
        tmp = pickle.load(f)
        print(type(tmp))
#         adj=[]
#         nodes=[]
#         relatedTo=[]
#         locatedIn=[]
#         appliedBy=[]
#         citedBy=[]
#         print(str(len(tmp.nodes)))
#         print("year: "+str(year))
#         print(tmp['adj']['locatedIn'])
#         print(str(len(tmp['adj']['relatedTo'].nodes))+"/"+str(len(tmp['adj']['relatedTo'].edges))+"/"+str(len(tmp['adj']['locatedIn'].nodes))+"/"+str(len(tmp['adj']['locatedIn'].edges))+"/"+str(len(tmp['adj']['appliedBy'].nodes))+"/"+str(len(tmp['adj']['appliedBy'].edges))+"/"+str(len(tmp['adj']['citedBy'].nodes))+"/"+str(len(tmp['adj']['citedBy'].edges)))
# Out:
# <class 'dict'>

# %%
def count_by_cpc(year):
    with open(path+'\\'+str(year)+'_patent_graph', 'rb') as f:
#     with open(AIPatent_path+'\\temporal_graph_'+str(year), 'rb') as f:
        res = pickle.load(f)

    cpc_count = {}
    for item in res['relatedTo']:
        if item[1] not in cpc_count:
            cpc_count[item[1]] = 0
        else:
            cpc_count[item[1]] += 1

    cpc_count = sorted(cpc_count.items(), key = lambda kv:(kv[1], kv[0]), reverse=True)
    return cpc_count

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

plt.style.use("ggplot")
fig, axes = plt.subplots(2,3,figsize=(15, 10), sharey=True)
axes = axes.flatten()
# years = [2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021]
years = [2017,2018,2019,2020,2021]
for i in range(5):
    cpc_count = count_by_cpc(years[i])
    X = []
    Y = []
    topK = 20
    for j in range(topK):
        X.append(cpc_count[j][0])
        Y.append(cpc_count[j][1])
    
    axes[i].bar(x=X, height=Y)
    axes[i].set_title("Top "+str(topK)+" in "+str(years[i]), fontsize=15)
    axes[i].set_xlabel("CPC")
plt.xticks(rotation=45)
plt.show()
